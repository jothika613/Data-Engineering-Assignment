# %%
import pandas as pd
import os
import json

# %% [markdown]
# # READING CSV FILE

# %%
csv="C:\\Users\\jothika\\joe\\finance.csv"

# %%
df_csv = pd.read_csv(csv)

# %%
df_csv
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2024                     Level 1                99999
# 1      2024                     Level 1                99999
# 2      2024                     Level 1                99999
# 3      2024                     Level 1                99999
# 4      2024                     Level 1                99999
# ...     ...                         ...                  ...
# 55615  2013                     Level 3                 ZZ11
# 55616  2013                     Level 3                 ZZ11
# 55617  2013                     Level 3                 ZZ11
# 55618  2013                     Level 3                 ZZ11
# 55619  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %% [markdown]
# # READING JSON FILE

# %%
json_path="C:\\Users\\jothika\\joe\\colors.json"

# %%
with open(json_path,"r")as f:
    raw_data=json.load(f)

# %%
df_json=pd.json_normalize(raw_data)

# %%
df_json
# Out:
#                                               colors
# 0  [{'name': 'Black', 'hex': '#000000', 'rgb': {'...

# %% [markdown]
# # READING PARQUET FILE

# %%
parquet_path="C:\\Users\\jothika\\joe\\iris.parquet"

# %%
df_parquet=pd.read_parquet(parquet_path)

# %%
df_parquet
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]
